# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishag7/DL_Bootcamp/blob/main/opencv_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/g_disneynaturepenguins_01_17789_d494d9a3.webp'

# %%
img = cv2.imread(path,1)

# %%
img.shape
# Out:
# (530, 1136, 3)

# %%
from google.colab.patches import cv2_imshow
#cv2_imshow(img) ; 
#cv2.waitKey(0) ; 
#cv2.destroyAllWindows()

# %%
resized_image = cv2.resize(img, (500,300))
cv2_imshow(resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F655A4ADED0>

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
cv2_imshow(gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1136x530 at 0x7F655A4ACDD0>
